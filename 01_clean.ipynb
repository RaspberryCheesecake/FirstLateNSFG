# %% [markdown]
# # Are first babies more likely to be late?
#
# Copyright 2019 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](http://creativecommons.org/licenses/by/4.0/)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: async-generator==1.10 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.10)
# Requirement already satisfied: attrs==20.2.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (20.2.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: bleach==3.2.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (3.2.1)
# Requirement already satisfied: certifi==2020.6.20 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (2020.6.20)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (0.3)
# Requirement already satisfied: idna==2.10 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 11)) (2.10)
# Requirement already satisfied: importlib-metadata==2.0.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: ipykernel==5.3.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 13)) (5.3.4)
# Requirement already satisfied: ipython==7.18.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 14)) (7.18.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 16)) (7.5.1)
# Requirement already satisfied: jedi==0.17.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 17)) (0.17.2)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 18)) (2.11.2)
# Requirement already satisfied: joblib==0.17.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 19)) (0.17.0)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: jupyter-client==6.1.7 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 21)) (6.1.7)
# Requirement already satisfied: jupyter-core==4.6.3 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 22)) (4.6.3)
# Requirement already satisfied: jupyterlab-pygments==0.1.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 23)) (0.1.2)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 24)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: matplotlib==3.3.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 26)) (3.3.2)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 27)) (0.8.4)
# Requirement already satisfied: nbclient==0.5.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 28)) (0.5.0)
# Requirement already satisfied: nbconvert==6.0.7 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 29)) (6.0.7)
# Requirement already satisfied: nbformat==5.0.7 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 30)) (5.0.7)
# Requirement already satisfied: nest-asyncio==1.4.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 31)) (1.4.1)
# Requirement already satisfied: notebook@ git+https://github.com/deepnote/jupyter-notebook.git@d339dce8272e707e4ab2255ec8609c96b52fc08d from git+https://github.com/deepnote/jupyter-notebook.git@d339dce8272e707e4ab2255ec8609c96b52fc08d in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 32)) (7.0.0.dev0)
# Requirement already satisfied: numpy==1.19.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 33)) (1.19.2)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 34)) (20.4)
# Requirement already satisfied: pandas==1.0.5 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 35)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 36)) (1.4.2)
# Requirement already satisfied: parso==0.7.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 37)) (0.7.1)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 38)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 39)) (0.7.5)
# Requirement already satisfied: Pillow==7.2.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 40)) (7.2.0)
# Requirement already satisfied: pluggy==1.0.0.dev0 in /opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg (from -r requirements.txt (line 41)) (1.0.0.dev0)
# Requirement already satisfied: prometheus-client==0.8.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 42)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.8 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 43)) (3.0.8)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 44)) (0.6.0)
# Requirement already satisfied: Pygments==2.7.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 45)) (2.7.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 46)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.17.3 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 47)) (0.17.3)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 48)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.4.0 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg (from -r requirements.txt (line 49)) (0.4.0)
# Requirement already satisfied: python-language-server===deepnote-0.03 in /opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg (from -r requirements.txt (line 50)) (deepnote-0.03)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 51)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 52)) (19.0.2)
# Requirement already satisfied: requests==2.24.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 53)) (2.24.0)
# Requirement already satisfied: scikit-learn==0.23.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 54)) (0.23.2)
# Requirement already satisfied: scipy==1.5.2 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 55)) (1.5.2)
# Requirement already satisfied: seaborn==0.11.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 56)) (0.11.0)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 57)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 58)) (1.15.0)
# Requirement already satisfied: terminado==0.9.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 59)) (0.9.1)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 60)) (0.4.4)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 61)) (2.1.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 62)) (6.0.4)
# Requirement already satisfied: traitlets==5.0.4 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 63)) (5.0.4)
# Requirement already satisfied: ujson==4.0.1 in /opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg (from -r requirements.txt (line 64)) (4.0.1)
# Requirement already satisfied: urllib3==1.25.10 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 65)) (1.25.10)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 66)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 67)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 68)) (3.5.1)
# Requirement already satisfied: zipp==3.3.0 in /opt/venv/lib/python3.7/site-packages (from -r requirements.txt (line 69)) (3.3.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.18.1->-r requirements.txt (line 14)) (50.3.0)
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from utils import read_stata_dict
from utils import values
from utils import resample_rows_weighted

# %%
def read_preg_file(dct_file, dat_file, usecols):
    """Reads the NSFG pregnancy data.

    dct_file: string file name
    dat_file: string file name

    returns: DataFrame
    """
    dct = read_stata_dict(dct_file, encoding='ISO-8859-1')
    df = dct.read_fixed_width(dat_file, compression='gzip', usecols=usecols)
    return df

# %% [markdown]
# Cycle 10

# %%
usecols = ['birthord', 'outcome', 'prglngth', 'pregend1', 'nbrnaliv', 'wgt2015_2017']
df = read_preg_file('2015_2017_FemPregSetup.dct', '2015_2017_FemPregData.dat.gz', usecols)
df.rename(columns={'wgt2015_2017': 'finalwgt'}, inplace=True)
print(df.shape)
# Out:
# (9553, 6)

# %%
values(df['outcome'])
# Out:
# 1    6693
# 2     901
# 3     120
# 4    1515
# 5     123
# 6     201
# Name: outcome, dtype: int64

# %%
values(df['prglngth'])
# Out:
# 0        5
# 1        7
# 2       46
# 3       77
# 4      250
# 5      142
# 6      421
# 7      153
# 8      282
# 9      335
# 10     154
# 11      76
# 12     139
# 13     237
# 14      38
# 15      32
# 16      41
# 17     100
# 18      12
# 19      20
# 20      27
# 21      16
# 22      54
# 23      13
# 24      17
# 25      14
# 26      69
# 27      17
# 28      27
# 29      11
# 30      87
# 31      33
# 32     104
# 33      47
# 34     105
# 35     191
# 36     276
# 37     423
# 38     776
# 39    2440
# 40    1521
# 41     438
# 42     215
# 43      56
# 44       8
# 49       1
# Name: prglngth, dtype: int64

# %%
values(df['pregend1'])
# Out:
# 1.0    1523
# 2.0     116
# 3.0     885
# 4.0     125
# 5.0    1865
# 6.0    4814
# 8.0      12
# 9.0       6
# Name: pregend1, dtype: int64

# %%
values(df['birthord'])
# Out:
# 1.0     3150
# 2.0     2107
# 3.0      941
# 4.0      325
# 5.0      104
# 6.0       38
# 7.0       13
# 8.0        5
# 9.0        2
# 10.0       2
# 11.0       2
# 12.0       2
# 13.0       1
# 14.0       1
# Name: birthord, dtype: int64

# %%
df['finalwgt'].describe()
# Out:
# count      9553.000000
# mean      13337.425944
# std       16138.878271
# min        1924.916000
# 25%        4575.221221
# 50%        7292.490835
# 75%       15724.902673
# max      106774.400000
# Name: finalwgt, dtype: float64

# %%
preg10 = df

# %% [markdown]
# Cycle 9

# %%
usecols = ['birthord', 'outcome', 'prglngth', 'pregend1', 'nbrnaliv', 'wgt2013_2015']
df = read_preg_file('2013_2015_FemPregSetup.dct', '2013_2015_FemPregData.dat.gz', usecols)
df.rename(columns={'wgt2013_2015': 'finalwgt'}, inplace=True)
print(df.shape)
# Out:
# (9358, 6)

# %%
values(df['outcome'])
# Out:
# 1    6489
# 2     947
# 3      86
# 4    1469
# 5     118
# 6     249
# Name: outcome, dtype: int64

# %%
values(df['prglngth'])
# Out:
# 0        7
# 1       11
# 2       50
# 3      102
# 4      274
# 5      128
# 6      375
# 7      185
# 8      299
# 9      331
# 10     125
# 11      82
# 12     132
# 13     222
# 14      39
# 15      27
# 16      40
# 17      85
# 18      25
# 19      25
# 20      21
# 21       9
# 22      76
# 23       7
# 24      25
# 25      13
# 26      58
# 27      17
# 28      39
# 29      25
# 30      95
# 31      15
# 32     118
# 33      35
# 34      73
# 35     239
# 36     313
# 37     432
# 38     755
# 39    2384
# 40    1311
# 41     422
# 42     231
# 43      65
# 44       9
# 45       3
# 46       3
# 48       1
# Name: prglngth, dtype: int64

# %%
values(df['pregend1'])
# Out:
# 1.0    1473
# 2.0      82
# 3.0     936
# 4.0     116
# 5.0    1842
# 6.0    4633
# 8.0      16
# 9.0       8
# Name: pregend1, dtype: int64

# %%
values(df['birthord'])
# Out:
# 1.0     3067
# 2.0     2002
# 3.0      937
# 4.0      322
# 5.0      106
# 6.0       32
# 7.0       14
# 8.0        6
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %%
df['finalwgt'].describe()
# Out:
# count     9358.000000
# mean     10759.200147
# std      11400.179222
# min       1859.105000
# 25%       4340.053407
# 50%       7062.994158
# 75%      12629.322982
# max      75399.410000
# Name: finalwgt, dtype: float64

# %%
preg09 = df

# %% [markdown]
# Cycle 8

# %%
usecols = ['birthord', 'outcome', 'prglngth', 'pregend1', 'nbrnaliv', 'wgt2011_2013']
df = read_preg_file('2011_2013_FemPregSetup.dct', '2011_2013_FemPregData.dat.gz', usecols)
df.rename(columns={'wgt2011_2013': 'finalwgt'}, inplace=True)
print(df.shape)
# Out:
# (9543, 6)

# %%
values(df['outcome'])
# Out:
# 1    6670
# 2     993
# 3      71
# 4    1451
# 5     120
# 6     238
# Name: outcome, dtype: int64

# %%
values(df['prglngth'])
# Out:
# 0       11
# 1       10
# 2       45
# 3      115
# 4      318
# 5      132
# 6      400
# 7      127
# 8      283
# 9      332
# 10     111
# 11      79
# 12     138
# 13     226
# 14      32
# 15      32
# 16      32
# 17      90
# 18      15
# 19      24
# 20      21
# 21      10
# 22      89
# 23      15
# 24      29
# 25      12
# 26      61
# 27      17
# 28      25
# 29      22
# 30      80
# 31      35
# 32     103
# 33      34
# 34     104
# 35     237
# 36     290
# 37     418
# 38     710
# 39    2590
# 40    1310
# 41     426
# 42     277
# 43      63
# 44       8
# 45       2
# 46       1
# 47       2
# Name: prglngth, dtype: int64

# %%
values(df['pregend1'])
# Out:
# 1.0    1459
# 2.0      69
# 3.0     981
# 4.0     121
# 5.0    1861
# 6.0    4795
# 8.0       7
# 9.0      12
# Name: pregend1, dtype: int64

# %%
values(df['birthord'])
# Out:
# 1.0    3141
# 2.0    2076
# 3.0     957
# 4.0     327
# 5.0     113
# 6.0      34
# 7.0      16
# 8.0       5
# 9.0       1
# Name: birthord, dtype: int64

# %%
df['finalwgt'].describe()
# Out:
# count     9543.000000
# mean     11040.049389
# std      13033.547986
# min       1714.541000
# 25%       3935.813218
# 50%       6641.818091
# 75%      12742.521135
# max      85207.950000
# Name: finalwgt, dtype: float64

# %%
preg08 = df

# %% [markdown]
# Cycle 7

# %%
usecols = ['birthord', 'outcome', 'prglngth', 'pregend1', 'nbrnaliv', 'wgtq1q16']
df = read_preg_file('2006_2010_FemPregSetup.dct', '2006_2010_FemPreg.dat.gz', usecols)
df.rename(columns={'wgtq1q16': 'finalwgt'}, inplace=True)
print(df.shape)
# Out:
# (20492, 6)

# %%
values(df['outcome'])
# Out:
# 1    14292
# 2     2295
# 3      166
# 4     2945
# 5      278
# 6      516
# Name: outcome, dtype: int64

# %%
values(df['prglngth'])
# Out:
# 0       11
# 1       19
# 2      117
# 3      219
# 4      561
# 5      274
# 6      896
# 7      271
# 8      513
# 9      770
# 10     275
# 11     173
# 12     248
# 13     685
# 14      79
# 15      88
# 16      53
# 17     241
# 18      36
# 19      45
# 20      39
# 21      24
# 22     174
# 23      14
# 24      45
# 25      24
# 26     151
# 27      29
# 28      59
# 29      36
# 30     248
# 31      44
# 32     173
# 33      69
# 34     164
# 35     558
# 36     636
# 37     848
# 38    1311
# 39    6308
# 40    2285
# 41     910
# 42     553
# 43     185
# 44      19
# 45       3
# 46       4
# 48       3
# 52       1
# 57       1
# Name: prglngth, dtype: int64

# %%
values(df['pregend1'])
# Out:
# 1.0     2958
# 2.0      165
# 3.0     2288
# 4.0      281
# 5.0     3420
# 6.0    10849
# 8.0        2
# 9.0        5
# Name: pregend1, dtype: int64

# %%
values(df['birthord'])
# Out:
# 1.0     6683
# 2.0     4415
# 3.0     2030
# 4.0      734
# 5.0      269
# 6.0      102
# 7.0       36
# 8.0       13
# 9.0        7
# 10.0       2
# 11.0       1
# Name: birthord, dtype: int64

# %%
df['finalwgt'].describe()
# Out:
# count    20492.000000
# mean      5195.422926
# std       5909.631184
# min         44.023984
# 25%       1480.501506
# 50%       2976.610130
# 75%       6351.218612
# max      30226.354508
# Name: finalwgt, dtype: float64

# %%
preg07 = df

# %% [markdown]
# Cycle 6

# %%
usecols = ['birthord', 'outcome', 'prglngth', 'pregend1', 'nbrnaliv', 'finalwgt']
df = read_preg_file('2002FemPreg.dct', '2002FemPreg.dat.gz', usecols)
print(df.shape)
# Out:
# (13593, 6)

# %%
values(df['outcome'])
# Out:
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: outcome, dtype: int64

# %%
values(df['prglngth'])
# Out:
# 0       15
# 1        9
# 2       78
# 3      151
# 4      412
# 5      181
# 6      543
# 7      175
# 8      409
# 9      594
# 10     137
# 11     202
# 12     170
# 13     446
# 14      29
# 15      39
# 16      44
# 17     253
# 18      17
# 19      34
# 20      18
# 21      37
# 22     147
# 23      12
# 24      31
# 25      15
# 26     117
# 27       8
# 28      38
# 29      23
# 30     198
# 31      29
# 32     122
# 33      50
# 34      60
# 35     357
# 36     329
# 37     457
# 38     609
# 39    4744
# 40    1120
# 41     591
# 42     328
# 43     148
# 44      46
# 45      10
# 46       1
# 47       1
# 48       7
# 50       2
# Name: prglngth, dtype: int64

# %%
values(df['pregend1'])
# Out:
# 1.0    1921
# 2.0     120
# 3.0    1831
# 4.0     187
# 5.0    2015
# 6.0    7129
# 8.0      20
# 9.0      18
# Name: pregend1, dtype: int64

# %%
values(df['birthord'])
# Out:
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: birthord, dtype: int64

# %%
df['finalwgt'].describe()
# Out:
# count     13593.000000
# mean       8196.422280
# std        9325.918114
# min         118.656790
# 25%        3841.375308
# 50%        6256.592133
# 75%        9432.360931
# max      261879.953864
# Name: finalwgt, dtype: float64

# %%
preg06 = df

# %%
cycles = [preg10, preg09, preg08, preg07, preg06]
df = pd.concat(cycles, sort=False, ignore_index=True)
df.shape
# Out:
# (62539, 6)

# %%
live = (df['outcome'] == 1)
live.sum()
# Out:
# 43292

# %%
multiple = (df['nbrnaliv'] > 1)
multiple.sum()
# Out:
# 737

# %%
737 / 43292
# Out:
# 0.01702393051834057

# %%
sec = (df['pregend1'] == 5)
sec.sum()
# Out:
# 11003

# %%
nosec = (df['pregend1'] == 6)
nosec.sum()
# Out:
# 32220

# %%
single = (df['nbrnaliv'] == 1)
single.sum()
# Out:
# 42542

# %%
valid = single & nosec
valid.sum()
# Out:
# 31909

# %%
valid = single & nosec & (df['prglngth'] < 50)
valid.sum()
# Out:
# 31906

# %%
def resample_by_cycle(dfs, column='finalwgt'):
    samples = [resample_rows_weighted(df, column) for df in dfs]
    sample = pd.concat(samples, sort=False, ignore_index=True)
    return sample

# %%
cycles = [preg10, preg09, preg08, preg07, preg06]
sample = resample_by_cycle(cycles)
sample.shape
# Out:
# (62539, 6)

# %%
sample.columns
# Out:
# Index(['pregend1', 'nbrnaliv', 'prglngth', 'outcome', 'birthord', 'finalwgt'], dtype='object')

# %%
# if the file already exists, remove it
import os

if os.path.isfile('nsfg.hdf5'):
    # !rm nsfg.hdf5

# %%
# generate and store three resamplings
for i in range(101):
    np.random.seed(i)
    sample = sample = resample_by_cycle(cycles)

    key = f'nsfg{i}'
    sample.to_hdf('nsfg.hdf5', key)

# %%
# read back one of the resamplings and time it
# %time nsfg = pd.read_hdf('nsfg.hdf5', 'nsfg0')
nsfg.shape
# Out:
# CPU times: user 10.3 ms, sys: 7.93 ms, total: 18.3 ms
# Wall time: 132 ms
# (62539, 6)
